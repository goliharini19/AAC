# %% [markdown]
# <a href="https://colab.research.google.com/github/goliharini19/AAC/blob/main/1_3_Assignment_1544ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Task 1 – Fibonacci Without Functions**

# %%
n = int(input("Enter number of terms: "))

a = 0
b = 1

if n <= 0:
    print("Please enter a positive number")
elif n == 1:
    print(a)
else:
    print(a, b, end=" ")
    for i in range(2, n):
        c = a + b
        print(c, end=" ")
        a = b
        b = c
# Out:
# Enter number of terms: 4
# 0 1 1 2

# %% [markdown]
# # **Task 2 – Optimized Fibonacci Code**

# %%
n = int(input("Enter number of terms: "))

a, b = 0, 1

for i in range(n):
    print(a, end=" ")
    a, b = b, a + b
# Out:
# Enter number of terms: 3
# 0 1 1

# %% [markdown]
# # **Task 3 – Fibonacci Using Functions**

# %%
def fibonacci(n):
    a, b = 0, 1
    for i in range(n):
        print(a, end=" ")
        a, b = b, a + b

n = int(input("Enter number of terms: "))
fibonacci(n)
# Out:
# Enter number of terms: 5
# 0 1 1 2 3

# %% [markdown]
# # **Task 4 – Iterative Fibonacci**

# %%
def fibonacci_iterative(n):
    a, b = 0, 1
    for i in range(n):
        print(a, end=" ")
        a, b = b, a + b

n = int(input("Enter number of terms: "))
fibonacci_iterative(n)
# Out:
# Enter number of terms: 7
# 0 1 1 2 3 5 8

# %% [markdown]
# # **Task 5 – Recursive Fibonacci**

# %%
def fibonacci_recursive(n):
    if n <= 1:
        return n
    return fibonacci_recursive(n - 1) + fibonacci_recursive(n - 2)

n = int(input("Enter number of terms: "))
for i in range(n):
    print(fibonacci_recursive(i), end=" ")
# Out:
# Enter number of terms: 5
# 0 1 1 2 3
